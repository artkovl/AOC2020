# %% [markdown]
# # Puzzle_09
# ## part 1

# %%
# Puzzle_09
## part 1 - TEST

def seek_numb(preamble, num):
    for ind, numm in enumerate(preamble):
        numm1_i = ind
        numm1 = numm
        print('ind1  =', numm1_i, numm1)
        for ind, numm in enumerate(preamble):
            numm2_i = ind
            numm2 = numm
            print('ind2=', numm2_i, numm2)
            if num == numm1 + numm2 and numm1_i != numm2_i:
                print(num, '=', numm1, '+', numm2)
                del preamble[0]
                preamble.append(num)
                return preamble
            else:
                if numm1_i == 4 and numm2_i == 4:
                    print(num, 'does not follow rules')
                    del preamble[0]
                    preamble.append(num)
                    return preamble
                    
                    
with open('09 input_test.txt') as fh:

    lines = []
    
    for line in fh:
        lines.append(int(line.strip()))
    preamble = lines[:5]
    print(lines)
    print(preamble)


                    
for num in lines[5:]:
    print('#', num)
    seek_numb(preamble, num)
    print(preamble, num)
# Out:
# [35, 20, 15, 25, 47, 40, 62, 55, 65, 95, 102, 117, 150, 182, 127, 219, 299, 277, 309, 576]
# [35, 20, 15, 25, 47]
# # 40
# ind1  = 0 35
# ind2= 0 35
# ind2= 1 20
# ind2= 2 15
# ind2= 3 25
# ind2= 4 47
# ind1  = 1 20
# ind2= 0 35
# ind2= 1 20
# ind2= 2 15
# ind2= 3 25
# ind2= 4 47
# ind1  = 2 15
# ind2= 0 35
# ind2= 1 20
# ind2= 2 15
# ind2= 3 25
# 40 = 15 + 25
# [20, 15, 25, 47, 40] 40
# # 62
# ind1  = 0 20
# ind2= 0 20
# ind2= 1 15
# ind2= 2 25
# ind2= 3 47
# ind2= 4 40
# ind1  = 1 15
# ind2= 0 20
# ind2= 1 15
# ind2= 2 25
# ind2= 3 47
# 62 = 15 + 47
# [15, 25, 47, 40, 62] 62
# # 55
# ind1  = 0 15
# ind2= 0 15
# ind2= 1 25
# ind2= 2 47
# ind2= 3 40
# 55 = 15 + 40
# [25, 47, 40, 62, 55] 55
# # 65
# ind1  = 0 25
# ind2= 0 25
# ind2= 1 47
# ind2= 2 40
# 65 = 25 + 40
# [47, 40, 62, 55, 65] 65
# # 95
# ind1  = 0 47
# ind2= 0 47
# ind2= 1 40
# ind2= 2 62
# ind2= 3 55
# ind2= 4 65
# ind1  = 1 40
# ind2= 0 47
# ind2= 1 40
# ind2= 2 62
# ind2= 3 55
# 95 = 40 + 55
# [40, 62, 55, 65, 95] 95
# ...

# %%
# Puzzle_09
## part 1

def seek_numb(preamble, num):
    for ind, numm in enumerate(preamble):
        numm1_i = ind
        numm1 = numm
        #print('ind1  =', numm1_i, numm1)
        for ind, numm in enumerate(preamble):
            numm2_i = ind
            numm2 = numm
            #print('ind2=', numm2_i, numm2)
            if num == numm1 + numm2 and numm1_i != numm2_i:
                #print(num, '=', numm1, '+', numm2)
                del preamble[0]
                preamble.append(num)
                return preamble
            else:
                if numm1_i == 24 and numm2_i == 24:
                    print(num, 'does not follow rules')
                    del preamble[0]
                    preamble.append(num)
                    return preamble
                    
                    
with open('09 input.txt') as fh:

    lines = []
    
    for line in fh:
        lines.append(int(line.strip()))
    preamble = lines[:25]
    #print(lines)
    #print(preamble)


                    
for num in lines[25:]:
    #print('#', num)
    seek_numb(preamble, num)
    #print(preamble, num)
# Out:
# 70639851 does not follow rules

# %%
# Puzzle_09
## part 2 - TEST

with open('09 input_test.txt') as fh:

    lines = []
    
    for line in fh:
        lines.append(int(line.strip()))
    
    print(lines)
# Out:
# [35, 20, 15, 25, 47, 40, 62, 55, 65, 95, 102, 117, 150, 182, 127, 219, 299, 277, 309, 576]

# %%
num_part1 = 127

def sum_srch(i):
    summ = 0
    cont_list = []
    while i < len(lines):
        summ += lines[i]
        if summ < num_part1:
            cont_list.append(lines[i])
            print(cont_list)
            i += 1
            continue
        elif summ == num_part1:
            cont_list.append(lines[i])
            print(cont_list)
            return cont_list
        else:
            return list()

for i in range(len(lines)):
    cont_list = sum_srch(i)
    print(cont_list)
    if len(cont_list) >= 2:
        print(cont_list, 'max =', max(cont_list), 'min =', min(cont_list), 'sum =', max(cont_list) + min(cont_list))
        break
# Out:
# [35]
# [35, 20]
# [35, 20, 15]
# [35, 20, 15, 25]
# []
# [20]
# [20, 15]
# [20, 15, 25]
# [20, 15, 25, 47]
# []
# [15]
# [15, 25]
# [15, 25, 47]
# [15, 25, 47, 40]
# [15, 25, 47, 40]
# [15, 25, 47, 40] max = 47 min = 15 sum = 62

# %%
# Puzzle_09
## part 2


def sum_srch(i):
    summ = 0
    cont_list = []
    while i < len(lines):
        summ += lines[i]
        if summ < num_part1:
            cont_list.append(lines[i])
            #print(cont_list)
            i += 1
            continue
        elif summ == num_part1:
            cont_list.append(lines[i])
            #print(cont_list)
            return cont_list
        else:
            return list()

with open('09 input.txt') as fh:

    lines = []
    
    for line in fh:
        lines.append(int(line.strip()))
    
#print(lines)

num_part1 = 70639851
        
for i in range(len(lines)):
    cont_list = sum_srch(i)
    #print(cont_list)
    if len(cont_list) >= 2:
        print(cont_list, 'max =', max(cont_list), 'min =', min(cont_list), 'sum =', max(cont_list) + min(cont_list))
        break
# Out:
# [3474524, 3622050, 4565780, 4288889, 3944976, 3686424, 3791474, 3909340, 3954069, 4067648, 4640672, 4155006, 4268585, 4134541, 4606906, 4774716, 4754251] max = 4774716 min = 3474524 sum = 8249240
